# %%
# !pip install instaloader
# Out:
# ...
#      ---------------------------------------- 0.0/62.9 kB ? eta -:--:--
#      ------------ ------------------------- 20.5/62.9 kB 320.0 kB/s eta 0:00:01
#      -------------------------------------- 62.9/62.9 kB 675.1 kB/s eta 0:00:00
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for instaloader: filename=instaloader-4.10.3-py3-none-any.whl size=64800 sha256=f7ba078f80abf4eef2b4de0720ab0acff2f8ebc70ad58286094290c2d71f5657
#   Stored in directory: c:\users\23036361\appdata\local\pip\cache\wheels\9b\01\a9\bada6c872bd7b19cdbdce06ed73cf35ec4cb4a335975d6d036
# Successfully built instaloader
# ...

# %%
# !instaloader zipa______
# Out:
# Hint: Use --login to download higher-quality versions of pictures.
# [1/1] Downloading profile zipa______
# zipa______\2022-09-30_10-20-57_UTC_profile_pic.jpg already exists
# Retrieving posts from profile zipa______.
# [   1/1215] zipa______\2021-01-15_00-02-21_UTC_1.jpg zipa______\2021-01-15_00-02-21_UTC_2.jpg [Un homenaje a nuestro pacífic…] json
# [   2/1215] zipa______\2023-05-18_23-18-39_UTC.jpg [Algunos para @conamordani . G…] zipa______\2023-05-18_23-18-39_UTC.mp4 json
# [   3/1215] zipa______\2022-03-07_01-56-49_UTC_1.jpg zipa______\2022-03-07_01-56-49_UTC_2.jpg zipa______\2022-03-07_01-56-49_UTC_3.jpg [Be wild n safe & mushroom & l…] json
# [   4/1215] zipa______\2024-02-12_18-00-09_UTC.jpg [A tattoo in honor of her brot…] json
# [   5/1215] zipa______\2024-02-10_17-45-27_UTC.jpg [Cariad —- Darling in Welsh. T…] json
# [   6/1215] zipa______\2024-02-08_16-05-45_UTC.jpg [Jaguar 🐆 gracias por la confi…] json
# ...

# %%
import cv2
import os





data_path = "Generative-Adversarial-Networks--GANs-main/Data"


output_path = "resized_grayscale_images"  

new_size = (512, 512)


# Get all image paths in the data folder
image_paths = [os.path.join(data_path, f) for f in os.listdir(data_path) if os.path.isfile(os.path.join(data_path, f))]

# Loop through each image path
for image_path in image_paths:
    try:
        # Read the image
        image = cv2.imread(image_path)

        # Check if image is read successfully
        if image is not None:
            # Used LLM to find the function for greyscale
            grayscale_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

            # Resize the image
            resized_image = cv2.resize(grayscale_image, new_size)

            # Create the full output path with unique filename
            output_filename = os.path.join(output_path, f"resized_grayscale_{os.path.basename(image_path)}")

            # Save the resized image
            cv2.imwrite(output_filename, resized_image)

            print(f"Image resized, converted to grayscale, and saved: {output_filename}")
        else:
            print(f"Error reading image: {image_path}")
    except Exception as e:
        print(f"Error processing image: {image_path} - {e}")

print("All images processed!")
# Out:
# Image resized, converted to grayscale, and saved: resized_grayscale_images\resized_grayscale_resized_2016-05-03_03-32-14_UTC_sq.jpg
# Image resized, converted to grayscale, and saved: resized_grayscale_images\resized_grayscale_resized_2016-05-19_04-08-12_UTC_sq.jpg
# Image resized, converted to grayscale, and saved: resized_grayscale_images\resized_grayscale_resized_2016-06-15_19-38-12_UTC_sq.jpg
# Image resized, converted to grayscale, and saved: resized_grayscale_images\resized_grayscale_resized_2016-07-27_05-27-21_UTC_sq.jpg
# Image resized, converted to grayscale, and saved: resized_grayscale_images\resized_grayscale_resized_2016-09-13_01-57-12_UTC_sq.jpg
# Image resized, converted to grayscale, and saved: resized_grayscale_images\resized_grayscale_resized_2016-12-06_01-25-22_UTC_sq.jpg
# Image resized, converted to grayscale, and saved: resized_grayscale_images\resized_grayscale_resized_2016-12-13_23-27-40_UTC_sq.jpg
# ...
